# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %% [markdown]
# # Load the Data

# %%
df=pd.read_csv('Mobile_phones_dataset.csv')

# %%
df
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0            Model        Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7   Night Black      64    4      6000
# 1           1  Infinix SMART 7    Azure Blue      64    4      6000
# 2           2     MOTOROLA G32  Mineral Gray     128    8      5000
# 3           3         POCO C50    Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i      Marigold     128    8      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# 2        50MP         16MP        0          16.64
# 3         8MP          5MP        0          16.56
# 4        50MP          5MP        1          16.76
#
#                    Processor_   Prize
# 0  Unisoc Spreadtrum SC9863A1   7,299
# 1  Unisoc Spreadtrum SC9863A1   7,299
# 2     Qualcomm Snapdragon 680  11,999
# 3          Mediatek Helio A22   5,649
# 4                         G37   8,999

# %%
df.tail()
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
#     Rear Camera Front Camera  AI Lens  Mobile Height  \
# 536        50MP         12MP        0          15.49
# 537         5MP          2MP        0          12.70
# 538        50MP          8MP        0          16.76
# 539        50MP         32MP        0          16.26
# 540        50MP          8MP        0          16.66
#
#                       Processor_   Prize
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# ...

# %%
df.shape
# Out:
# (541, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %% [markdown]
# # Check Unique Value and Len value

# %%
df['Model'].value_counts()
# Out:
# Model
# vivo Y16                 9
# realme C55               9
# SAMSUNG Galaxy A14 5G    9
# REDMI Note 12 Pro 5G     9
# vivo T1 44W              8
#                         ..
# vivo Y1s                 1
# OnePlus Nord             1
# Micromax 3               1
# vivo Y33s                1
# OPPO A77                 1
# Name: count, Length: 187, dtype: int64

# %%
len(df['Model'].unique())
# Out:
# 187

# %%
df['Colour'].value_counts()
# Out:
# Colour
# Yellow            12
# Royal Blue         8
# Power Black        8
# Black              8
# Midnight Black     7
#                   ..
# Polar Blue         1
# Cosmic grey        1
# Sea                1
# Infinity Black     1
# Sky Blue           1
# Name: count, Length: 275, dtype: int64

# %%
df['AI Lens'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# Model             object
# Colour            object
# Memory             int64
# RAM                int64
# Battery_           int64
# Rear Camera       object
# Front Camera      object
# AI Lens            int64
# Mobile Height    float64
# Processor_        object
# Prize             object
# dtype: object

# %% [markdown]
# # Describe the Data

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0     Model  Colour      Memory         RAM     Battery_  \
# count   541.000000       541     541  541.000000  541.000000   541.000000
# unique         NaN       187     275         NaN         NaN          NaN
# top            NaN  vivo Y16  Yellow         NaN         NaN          NaN
# freq           NaN         9      12         NaN         NaN          NaN
# mean    289.711645       NaN     NaN  110.550832    5.397412  4871.587800
# std     182.359185       NaN     NaN   60.600694    1.984923   780.148862
# min       0.000000       NaN     NaN   16.000000    2.000000   800.000000
# 25%     135.000000       NaN     NaN   64.000000    4.000000  5000.000000
# 50%     273.000000       NaN     NaN  128.000000    6.000000  5000.000000
# 75%     434.000000       NaN     NaN  128.000000    8.000000  5000.000000
# max     642.000000       NaN     NaN  256.000000    8.000000  7000.000000
#
#        Rear Camera Front Camera     AI Lens  Mobile Height  \
# ...

# %% [markdown]
# # Rename the column

# %%
df.rename(columns={'Prize':'Price'},inplace=True)

# %% [markdown]
# # Check Price value counts

# %%
df.Price.value_counts()
# Out:
# Price
# 15,999    23
# 9,999     22
# 16,999    21
# 8,999     20
# 23,999    19
#           ..
# 20,998     1
# 29,499     1
# 8,495      1
# 8,449      1
# 38,999     1
# Name: count, Length: 158, dtype: int64

# %% [markdown]
# # Checking for Missing Values and Duplicate values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Price            0
# dtype: int64

# %%
dict(df.isnull().sum())
# Out:
# {'Unnamed: 0': 0,
#  'Model': 0,
#  'Colour': 0,
#  'Memory': 0,
#  'RAM': 0,
#  'Battery_': 0,
#  'Rear Camera': 0,
#  'Front Camera': 0,
#  'AI Lens': 0,
#  'Mobile Height': 0,
#  'Processor_': 0,
#  'Price': 0}

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
n_df=df.drop(['Unnamed: 0'],axis=1)

# %%
n_df
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black      64    4      6000        13MP
# 1          Infinix SMART 7      Azure Blue      64    4      6000        13MP
# 2             MOTOROLA G32    Mineral Gray     128    8      5000        50MP
# 3                 POCO C50      Royal Blue      32    2      5000         8MP
# 4          Infinix HOT 30i        Marigold     128    8      5000        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900        50MP
# 537               LAVA Z21            Cyan      32    2      3100         5MP
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000        50MP
# 540               OPPO A77        Sky Blue     128    4      5000        50MP
#
# ...

# %%
df['Model'].unique()
# Out:
# array(['Infinix SMART 7', 'MOTOROLA G32', 'POCO C50', 'Infinix HOT 30i',
#        'REDMI 10', 'SAMSUNG Galaxy F13', 'SAMSUNG Galaxy F04', 'POCO C51',
#        'MOTOROLA e13', 'vivo T2x 5G', 'Infinix Smart 7 HD', 'REDMI A1+',
#        'POCO C55', 'MOTOROLA g13', 'POCO M4 5G', 'MOTOROLA e32',
#        'vivo T2 5G', 'MOTOROLA G62 5G', 'POCO M5', 'realme C33 2023',
#        'SAMSUNG Galaxy F14 5G', 'MOTOROLA g73 5G', 'realme C30',
#        'POCO X5 5G', 'POCO M4 Pro', 'REDMI 11 Prime', 'realme C55',
#        'realme 10 Pro 5G', 'Micromax IN 2C', 'POCO M4 Pro 5G',
#        'realme Narzo 30 Pro 5G', 'micromax 2', 'Infinix Note 12 Pro 5G',
#        'SAMSUNG Galaxy F23 5G', 'micromax', 'MOTOROLA Edge 40',
#        'micromax 1', 'realme Narzo 30', 'Infinix NOTE 12i', 'realme 10',
#        'realme 8i', 'Micromax 3', 'Google Pixel 6a', 'Infinix HOT 20 5G',
#        'realme GT 2', 'REDMI Note 12', 'REDMI Note 12 5G', 'micromax 3',
#        'SAMSUNG Galaxy M04', 'REDMI K50i 5G', 'MOTOROLA e40',
# ...

# %%
n_df.columns
# Out:
# Index(['Model', 'Colour', 'Memory', 'RAM', 'Battery_', 'Rear Camera',
#        'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_', 'Price'],
#       dtype='object')

# %%
n_df.drop_duplicates(subset=['Model','Colour',],inplace= True)
n_df
# Out:
#                      Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 0          Infinix SMART 7     Night Black      64    4      6000        13MP
# 1          Infinix SMART 7      Azure Blue      64    4      6000        13MP
# 2             MOTOROLA G32    Mineral Gray     128    8      5000        50MP
# 3                 POCO C50      Royal Blue      32    2      5000         8MP
# 4          Infinix HOT 30i        Marigold     128    8      5000        50MP
# ..                     ...             ...     ...  ...       ...         ...
# 536  SAMSUNG Galaxy S23 5G           Cream     256    8      3900        50MP
# 537               LAVA Z21            Cyan      32    2      3100         5MP
# 538         Tecno Spark 8T  Turquoise Cyan      64    4      5000        50MP
# 539  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000        50MP
# 540               OPPO A77        Sky Blue     128    4      5000        50MP
#
# ...

# %%
n_df['Model'].unique()
# Out:
# array(['Infinix SMART 7', 'MOTOROLA G32', 'POCO C50', 'Infinix HOT 30i',
#        'REDMI 10', 'SAMSUNG Galaxy F13', 'SAMSUNG Galaxy F04', 'POCO C51',
#        'MOTOROLA e13', 'vivo T2x 5G', 'Infinix Smart 7 HD', 'REDMI A1+',
#        'POCO C55', 'MOTOROLA g13', 'POCO M4 5G', 'MOTOROLA e32',
#        'vivo T2 5G', 'MOTOROLA G62 5G', 'POCO M5', 'realme C33 2023',
#        'SAMSUNG Galaxy F14 5G', 'MOTOROLA g73 5G', 'realme C30',
#        'POCO X5 5G', 'POCO M4 Pro', 'REDMI 11 Prime', 'realme C55',
#        'realme 10 Pro 5G', 'Micromax IN 2C', 'POCO M4 Pro 5G',
#        'realme Narzo 30 Pro 5G', 'micromax 2', 'Infinix Note 12 Pro 5G',
#        'SAMSUNG Galaxy F23 5G', 'micromax', 'MOTOROLA Edge 40',
#        'micromax 1', 'realme Narzo 30', 'Infinix NOTE 12i', 'realme 10',
#        'realme 8i', 'Micromax 3', 'Google Pixel 6a', 'Infinix HOT 20 5G',
#        'realme GT 2', 'REDMI Note 12', 'REDMI Note 12 5G', 'micromax 3',
#        'SAMSUNG Galaxy M04', 'REDMI K50i 5G', 'MOTOROLA e40',
# ...

# %%
n_df['Price']=n_df['Price'].str.replace(',','').astype(float)

# %%
n_df.Price
# Out:
# 0       7299.0
# 1       7299.0
# 2      11999.0
# 3       5649.0
# 4       8999.0
#         ...
# 536    79999.0
# 537     5998.0
# 538     9990.0
# 539    38999.0
# 540    15999.0
# Name: Price, Length: 386, dtype: float64

# %% [markdown]
# # Check Outliers

# %%
sns.boxplot(data=n_df,x='Memory')
plt.show()

# %%
sns.boxplot(data=n_df,x='Rear Camera')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # One Hot Encoding using with Sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
cat_col= ['Model','Colour','Rear Camera','Front Camera','Processor_']
dummy= pd.get_dummies(n_df,columns=cat_col,dtype=int)

# %%
dummy
# Out:
#      Memory  RAM  Battery_  AI Lens  Mobile Height    Price  \
# 0        64    4      6000        1          16.76   7299.0
# 1        64    4      6000        1          16.76   7299.0
# 2       128    8      5000        0          16.64  11999.0
# 3        32    2      5000        0          16.56   5649.0
# 4       128    8      5000        1          16.76   8999.0
# ..      ...  ...       ...      ...            ...      ...
# 536     256    8      3900        0          15.49  79999.0
# 537      32    2      3100        0          12.70   5998.0
# 538      64    4      5000        0          16.76   9990.0
# 539     128    8      5000        0          16.26  38999.0
# 540     128    4      5000        0          16.66  15999.0
#
#      Model_APPLE iPhone 11  Model_APPLE iPhone 12  Model_APPLE iPhone 14 Plus  \
# 0                        0                      0                           0
# 1                        0                      0                           0
# ...

# %% [markdown]
# # Split the dataset into training and testing sets (80% train, 20% test)

# %%
x_train,x_test,y_train,y_test= train_test_split(dummy.drop('Price',axis=1),dummy['Price'],test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Memory  RAM  Battery_  AI Lens  Mobile Height  Model_APPLE iPhone 11  \
# 373      64    2      5000        0          16.76                      0
# 529      64    4      5000        0          16.51                      0
# 516      32    2      5000        0          16.51                      0
# 123      64    2      5000        1          16.76                      0
# 320     128    6      5000        0          16.76                      0
# ..      ...  ...       ...      ...            ...                    ...
# 110     128    8      5000        0          17.02                      0
# 153      64    4      5000        0          16.51                      0
# 392     128    8      5000        0          16.33                      0
# 497      64    4      5200        0          16.76                      0
# 147     128    6      5000        0          16.94                      0
#
#      Model_APPLE iPhone 12  Model_APPLE iPhone 14 Plus  Model_Google Pixel 6a  \
# ...

# %%
x_test
# Out:
#      Memory  RAM  Battery_  AI Lens  Mobile Height  Model_APPLE iPhone 11  \
# 485      64    6      5000        0          16.76                      0
# 446     128    8      5000        0          16.76                      0
# 134     128    6      5000        0          16.51                      0
# 384      64    3      5000        0          16.66                      0
# 215     128    8      5000        0          16.76                      0
# ..      ...  ...       ...      ...            ...                    ...
# 22      128    8      5000        0          16.71                      0
# 193      32    4      1020        0           6.10                      0
# 508     128    4      6000        0          16.51                      0
# 239     128    8      4600        0          17.22                      0
# 96      128    8      5000        0          17.07                      0
#
#      Model_APPLE iPhone 12  Model_APPLE iPhone 14 Plus  Model_Google Pixel 6a  \
# ...

# %%
y_train
# Out:
# 373     6999.0
# 529     8460.0
# 516     7499.0
# 123     6199.0
# 320    18999.0
#         ...
# 110    15999.0
# 153     7961.0
# 392    13999.0
# 497     9999.0
# 147    18999.0
# Name: Price, Length: 308, dtype: float64

# %%
y_test
# Out:
# 485     9999.0
# 446    19397.0
# 134    12499.0
# 384     9790.0
# 215    21499.0
#         ...
# 22     15999.0
# 193     2499.0
# 508    11762.0
# 239    32999.0
# 96     19999.0
# Name: Price, Length: 78, dtype: float64

# %% [markdown]
# # Feature extraction

# %% [markdown]
# # Calculate correlation coefficients

# %%
corre = dummy.corr()
price_correlation = corre['Price'].sort_values(ascending=False)

print("Correlation with Price:")
print(price_correlation)
# Out:
# Correlation with Price:
# Price                         1.000000
# Front Camera_12MP             0.565346
# RAM                           0.542323
# Memory                        0.511423
# Model_APPLE iPhone 14 Plus    0.482671
#                                 ...
# Rear Camera_0MP              -0.196745
# Rear Camera_13MP             -0.233555
# Front Camera_0MP             -0.241011
# Rear Camera_8MP              -0.277624
# Front Camera_5MP             -0.387210
# Name: Price, Length: 615, dtype: float64

# %%
#n_df['Price']=n_df['Price'].str.replace(',','').astype(float)
selected_columns = ['Memory','RAM','Battery_' ,'Price']

# Creating a correlation matrix for selected columns
corre = n_df[selected_columns].corr()

#Visualize relationships between selected features and target variable
plt.figure(figsize=(8, 6))
sns.heatmap(corre, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap for Selected Columns')
plt.show()

# %%
# Visualizations: Scatter plot of Price vs. RAM
plt.figure(figsize=(8, 6))
sns.scatterplot(data=n_df, x='RAM', y='Price')
plt.title('RAM vs. Price')
plt.xlabel('RAM')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Choose a machine learning algorithm (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
model = LinearRegression()

# %%
# Train the model on the training set
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the testing set
y_pred = model.predict(x_test)

# %%
# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 1.2016617691818648e+20

# %% [markdown]
# # Choose a machine learning algorithm (Decision Tree)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
# Train the model on the training set

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Make prediction on the training set

# %%
y_pred= model.predict(x_test)

# %%
y_pred
# Out:
# array([ 9999., 18999., 15999.,  6999., 15499., 12990.,  1449., 18999.,
#         8999.,  9499., 16999., 15999., 13489., 11999.,  7370., 16988.,
#        11999., 15999.,  9790.,  6999.,  9699.,  6799.,  7299.,  7299.,
#         8499.,  7299., 21999., 15999., 17499.,  7299., 41199.,  1375.,
#         9499., 23999., 13499., 13999., 13999., 16999., 16990.,  9999.,
#        15499.,  9999., 17999., 15499., 10999., 16999.,  9999., 16999.,
#         9499.,  7299.,  7299., 29999., 11499., 29999., 10799., 15999.,
#        13490., 16499., 18999.,  6999., 19999.,  6299.,  7299., 43999.,
#         8999.,  9999.,  1449.,  7299.,  9999.,  9999., 29999., 14999.,
#         6999., 15999.,  2499., 10699., 32999., 19999.])

# %%
# Evaluate the model's performance

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 27983188.487179488

# %% [markdown]
# # Model Building:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
# Evaluate the model's performance
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

# %%
mae
# Out:
# 2015.8974358974358

# %%
rmse
# Out:
# 5289.913844967561

# %%
r2
# Out:
# 0.6740118955485753

# %%
# Analyze feature importances
feature_importances = pd.Series(model.feature_importances_, index=x_train.columns).sort_values(ascending=False)

# %%
feature_importances
# Out:
# Front Camera_12MP            0.337871
# RAM                          0.242273
# Battery_                     0.158533
# Model_Google Pixel 7         0.049171
# Rear Camera_200MP            0.035217
#                                ...
# Colour_Drizzling Gold        0.000000
# Colour_Diamond White         0.000000
# Colour_Deepsea Luster        0.000000
# Colour_Deep Ocean Blue       0.000000
# Processor__snapdragon 888    0.000000
# Length: 614, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Feature Importance Analysis
# Train a Random Forest model
rf_model = RandomForestRegressor()
rf_model.fit(x_train, y_train)

# Extract feature importances
feature_importances = pd.Series(rf_model.feature_importances_, index=x_train.columns).sort_values(ascending=False)

# %%
feature_importances
# Out:
# Front Camera_12MP             0.258276
# RAM                           0.158215
# Battery_                      0.128108
# Memory                        0.122014
# Model_APPLE iPhone 14 Plus    0.042879
#                                 ...
# Colour_Midnight               0.000000
# Model_OPPO A17K               0.000000
# Model_OnePlus Nord            0.000000
# Colour_Night Black            0.000000
# Colour_Luna Blue              0.000000
# Length: 614, dtype: float64

# %% [markdown]
# #  Report and Visualization:

# %%
# Create visualizations and summary report based on the findings
# For example, you can create bar plots for feature importances:
plt.figure(figsize=(10, 6))
feature_importances[:10].plot(kind='bar')
plt.title('Top 10 Features by Importance')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.show()

# %% [markdown]
# # Recommendations:

# %%
# Provide recommendations based on the analysis
# For example, based on feature importances, suggest focusing on certain features for pricing strategies.
print("Recommendations:")
print("Based on feature importance analysis, focus on optimizing features with high importance for pricing strategies.")
# Out:
# Recommendations:
# Based on feature importance analysis, focus on optimizing features with high importance for pricing strategies.
